# %% [markdown]
# # Export to JSON

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
# c.Username = "realDonaldTrump"
c.Search = "IBM stock"
c.Store_json = True
c.Output = "D:\git\stonks\ibmJSON.json"

# Run
twint.run.Search(c)
# Out:
# 1451279812459470855 2021-10-22 01:40:45 +0530 <BeFullyInformed> Here is a trade in $IBM today as the stock plunges. Make sure to read the full trade article to understand the setup and particularly how protection is setup and used in the trade.   https://t.co/Aqvb4dMqg7
# 1451277142055165959 2021-10-22 01:30:08 +0530 <WheresStock> Stock Market is Closed! 10-21-2021 Results: GPS: --0.30 %, KSS: --0.25 %, XOM: +0.53 %, BP: --0.26 %, IBM: --0.34 %, PYPL: --0.25 %
# 1451275913933565960 2021-10-22 01:25:15 +0530 <Buguisim> $IBM... Is IBM's Stock Stock Overvalued Or Undervalued? Follow us @WebullGlobal    https://t.co/jSXRC7QFBl
# 1451273978715131904 2021-10-22 01:17:34 +0530 <TINIBMNews> 5 Top Stock Decliners for Thursday: IBM, PayPal, Krispy Kreme (Vidhi Choudhary/TheStreet.com - Investing)  https://t.co/KjYCRMNY9y
# ...

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
data = pd.read_json("D:\git\stonks\ibmJSON.json", lines=True)

# %%
data.shape
# Out:
# (322, 36)

# %%
data.head()
# Out:
#                     id      conversation_id  \
# 0  1451279812459470855  1451279812459470848
# 1  1451277142055165959  1451277142055165952
# 2  1451275913933565960  1451275913933565952
# 3  1451273978715131904  1451273978715131904
# 4  1451272929287684096  1451272929287684096
#
#                                 created_at       date      time  timezone  \
# 0  2021-10-22 01:40:45 India Standard Time 2021-10-22  01:40:45       530
# 1  2021-10-22 01:30:08 India Standard Time 2021-10-22  01:30:08       530
# 2  2021-10-22 01:25:15 India Standard Time 2021-10-22  01:25:15       530
# 3  2021-10-22 01:17:34 India Standard Time 2021-10-22  01:17:34       530
# 4  2021-10-22 01:13:24 India Standard Time 2021-10-22  01:13:24       530
#
#                user_id         username                      name place  \
# 0            606615769  befullyinformed              Teddi Knight
# 1  1399090370940530688      wheresstock         DudeWheresMyStock
# ...
