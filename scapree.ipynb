# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
# c.Username = "realDonaldTrump"
c.Search = "IBM stock"
c.Store_csv = True
c.Output = "D:\git\stonks\ibm.csv"

# Run
twint.run.Search(c)
# Out:
# 1451200067700879362 2021-10-21 20:23:52 +0530 <SeanLeeRocks1> IBM stock floored today after an earnings beat with a $3 price adjustment to $172 per share. #overeaction
# 1451196416185888769 2021-10-21 20:09:22 +0530 <PesseMessy> NEXT $FB $AAPL $TWTR   $DWAC HALT UP IMMINENT 140M &amp; RISING #USA #TRUMP   #stock #stocks #StockMarket #china $Baba $pltr $mrna $pfe $SPY $MRNA $DHR $SOS $NXTP $NVDA $AMD $pdd $nio $wkhs $c $csco $wmt $snap $T $PINS $PYPL $IBM $DHR $sos $nxtp $vlo $siox $va $sbx $snap $f #btc  https://t.co/E5khNNsKTg
# 1451194491004604432 2021-10-21 20:01:43 +0530 <royalpurple1976> @rosemontseneca Do you still believe intel is cheapest stock in America or would you consider ibm as new #1
# 1451194134715252741 2021-10-21 20:00:18 +0530 <MikeStroup10> @lhamtil The only stock safe to short in a post GameStop world is IBM
# 1451192998323130377 2021-10-21 19:55:47 +0530 <rosemontseneca> buying our niece some $IBM stock for her bat mitzvah  favorite uncle secured.
# ...

# %%
import pandas as pd
pd.options.display.max_columns = 100

# %%
data = pd.read_csv("D:\git\stonks\ibm.csv")

# %%
data.shape
# Out:
# (237, 36)

# %%
data.head()
# Out:
#                     id      conversation_id  \
# 0  1451200067700879362  1451200067700879362
# 1  1451196416185888769  1451196416185888769
# 2  1451194491004604432  1451192998323130377
# 3  1451194134715252741  1451182181078999040
# 4  1451192998323130377  1451192998323130377
#
#                                 created_at        date      time  timezone  \
# 0  2021-10-21 20:23:52 India Standard Time  2021-10-21  20:23:52       530
# 1  2021-10-21 20:09:22 India Standard Time  2021-10-21  20:09:22       530
# 2  2021-10-21 20:01:43 India Standard Time  2021-10-21  20:01:43       530
# 3  2021-10-21 20:00:18 India Standard Time  2021-10-21  20:00:18       530
# 4  2021-10-21 19:55:47 India Standard Time  2021-10-21  19:55:47       530
#
#                user_id         username                name  place  \
# 0           2321180159    seanleerocks1         King Dingle    NaN
# 1  1290767371590758400       pessemessy     Advance Society    NaN
# ...
